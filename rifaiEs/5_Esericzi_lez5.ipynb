# %% [markdown]
# # 4. Rispondere alle domande
# Trasforma le seguenti richiesti in formule per estrarre infromazioni dal dataframe
# - Mostrami le vendite maggiori di 10
#
# - Mostrami i dati del 2018
#
# - Mostrami le vendite maggiori di 13 e l'anno è il 2018
#
# - Mostrami tutto TRANNE i casi in cui le vendite sono maggiori di 13 e l'anno è il 2018
#
# - Mostrami i dati dove le vendite divise per 3 sono maggiori di 3
#
# - Mostrami i dipendenti i cui nomi sono alfabeticamente dopo la J

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

sales = pd.DataFrame(
    data={
        "employee": [
            "Katrina",
            "Guanyu",
            "Jan",
            "Roman",
            "Jacqueline",
            "Paola",
            "Esperanza",
            "Alaina",
            "Egweyn",
        ],
        "sales": [14, 17, 6, 12, 8, 3, 7, 15, 5],
        "year": [2018, 2019, 2020, 2018, 2020, 2019, 2019, 2020, 2020],
    }
)
sales
# Out:
#      employee  sales  year
# 0     Katrina     14  2018
# 1      Guanyu     17  2019
# 2         Jan      6  2020
# 3       Roman     12  2018
# 4  Jacqueline      8  2020
# 5       Paola      3  2019
# 6   Esperanza      7  2019
# 7      Alaina     15  2020
# 8      Egweyn      5  2020

# %%
# - Mostrami le vendite maggiori di 10
print(sales[sales['sales'] > 10])
# Out:
#   employee  sales  year
# 0  Katrina     14  2018
# 1   Guanyu     17  2019
# 3    Roman     12  2018
# 7   Alaina     15  2020

# %%
# - Mostrami i dati del 2018
print(sales[sales["year"] == 2018])
# Out:
#   employee  sales  year
# 0  Katrina     14  2018
# 3    Roman     12  2018

# %%
# - Mostrami le vendite maggiori di 13 e l'anno è il 2018
print(sales[sales["sales"] > 13][sales["year"] == 2018])
# Out:
#   employee  sales  year
# 0  Katrina     14  2018
# C:\Users\acer\AppData\Local\Temp\ipykernel_7716\2308781755.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(sales[sales["sales"] > 13][sales["year"] == 2018])

# %%
# - Mostrami tutto TRANNE i casi in cui le vendite sono maggiori di 13 e l'anno è il 2018
print(sales[sales["sales"] <13][sales["year"] != 2018])
# Out:
#      employee  sales  year
# 2         Jan      6  2020
# 4  Jacqueline      8  2020
# 5       Paola      3  2019
# 6   Esperanza      7  2019
# 8      Egweyn      5  2020
# C:\Users\acer\AppData\Local\Temp\ipykernel_7716\3788844144.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(sales[sales["sales"] <13][sales["year"] != 2018])

# %%
# - Mostrami i dati dove le vendite divise per 3 sono maggiori di 3
print(sales[sales["sales"] / 3 > 3])
# Out:
#   employee  sales  year
# 0  Katrina     14  2018
# 1   Guanyu     17  2019
# 3    Roman     12  2018
# 7   Alaina     15  2020

# %%
# - Mostrami i dipendenti i cui nomi sono alfabeticamente dopo la J
print(sales[sales['employee'] > 'J'])
# Out:
#      employee  sales  year
# 0     Katrina     14  2018
# 2         Jan      6  2020
# 3       Roman     12  2018
# 4  Jacqueline      8  2020
# 5       Paola      3  2019

# %% [markdown]
# # 5. Analisi di un dataset di video giochi
# 1. Quanti videogiochi sono stati pubblicati
# 2. Quali sono i generi più popolari? Mostralo con un bar plot
# 3. Plotta l'evoluzione del numero di giochi pubblicati nel tempo
# 4. Prova a riprodurre questo plot
# ![image.png](attachment:image.png)

# %%
# Import dei pacchetti
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Caricamento del dataset
url = 'https://zenodo.org/record/5898311/files/vgsales.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# 1. Quanti videogiochi sono stati pubblicati
print(f"Numero di videogiochi pubblicati: {df.shape[0]}")
# Out:
# Numero di videogiochi pubblicati: 16598

# %%
# 2. Quali sono i generi più popolari? Mostralo con un bar plot
giochiPiuPopolari = df['Genre'].value_counts()
giochiPiuPopolari.plot(kind='bar')
plt.title('Numero di videogiochi per genere')
plt.xlabel('Genere')
plt.ylabel('Numero di videogiochi')
plt.show()
""" df['Genre'].value_counts().plot(kind='bar')
plt.title('Numero di videogiochi per genere')
plt.xlabel('Genere')
plt.ylabel('Numero di videogiochi')
plt.show() """
# Out:
# " df['Genre'].value_counts().plot(kind='bar')\nplt.title('Numero di videogiochi per genere')\nplt.xlabel('Genere')\nplt.ylabel('Numero di videogiochi')\nplt.show() "

# %%
# 3. Plotta l'evoluzione del numero di giochi pubblicati nel tempo
# Utilizziamo il dataframe 'df' per i videogiochi pubblicati nel tempo

years = df['Year'].dropna().astype(int).value_counts().sort_index()
years.plot(kind='line')
plt.title('Evoluzione del numero di giochi pubblicati nel tempo')
plt.xlabel('Anno')
plt.ylabel('Numero di giochi')
plt.grid(True)

""" year_counts = df['Year'].dropna().astype(int).value_counts().sort_index()

plt.figure(figsize=(12, 6))
year_counts.plot(kind='line')
plt.title('Evoluzione del numero di giochi pubblicati nel tempo')
plt.xlabel('Anno')
plt.ylabel('Numero di giochi')
plt.grid(True)
plt.xticks(rotation=45)
plt.show() """
# Out:
# " year_counts = df['Year'].dropna().astype(int).value_counts().sort_index()\n\nplt.figure(figsize=(12, 6))\nyear_counts.plot(kind='line')\nplt.title('Evoluzione del numero di giochi pubblicati nel tempo')\nplt.xlabel('Anno')\nplt.ylabel('Numero di giochi')\nplt.grid(True)\nplt.xticks(rotation=45)\nplt.show() "

# %%
# vendite per regione e genere
# Creiamo un DataFrame con le vendite per regione e genere
salesRegionGenre = df.groupby(['Genre'])[['NA_Sales', 'EU_Sales', 'JP_Sales', "Other_Sales"]].sum().reset_index()
salesRegionGenre.plot(kind='bar', x='Genre', stacked=True, figsize=(12, 6))
plt.title('Vendite per regione e genere')
plt.xlabel('Genere')
plt.ylabel('Vendite (in milioni)')
plt.legend(title='Regione')
plt.show()
""" sales_by_region_genre = df.groupby(['Genre'])[['NA_Sales', 'EU_Sales', 'JP_Sales', "Other_Sales"]].sum().reset_index()
plt.figure(figsize=(12, 6))
sales_by_region_genre.plot(kind='bar', x='Genre', stacked=True)
plt.title('Vendite per regione e genere')
plt.xlabel('Genere')
plt.ylabel('Vendite (in milioni)')
plt.legend(title='Regione')
 """
# Out:
# ' sales_by_region_genre = df.groupby([\'Genre\'])[[\'NA_Sales\', \'EU_Sales\', \'JP_Sales\', "Other_Sales"]].sum().reset_index()\nplt.figure(figsize=(12, 6))\nsales_by_region_genre.plot(kind=\'bar\', x=\'Genre\', stacked=True)\nplt.title(\'Vendite per regione e genere\')\nplt.xlabel(\'Genere\')\nplt.ylabel(\'Vendite (in milioni)\')\nplt.legend(title=\'Regione\')\n '
